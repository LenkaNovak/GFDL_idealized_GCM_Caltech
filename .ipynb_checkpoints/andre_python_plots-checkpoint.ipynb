# %% [markdown]
# # DG H-S Paper: FMS comparison

# %%
#modules
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from scipy import ndimage
from scipy import integrate

# %%
def print_ncinfo(dataset):
    for var in dataset.variables:
        var1 = dataset.variables[var]
        for name in var1.ncattrs():
            print var, '-->',name, '=', getattr(var1,name)
            
def append_year_days_onevar(fn, day_list, var_name, enable_print_ncinfo=False):
    ncdata =Dataset(fn%1,'r')
    if enable_print_ncinfo==True:
        print_ncinfo(ncdata)
    zon_waven = ncdata.variables['zon_waven'][:]
    legendre = ncdata.variables['legendre'][:]
    lat = ncdata.variables['lat'][:]
    lon = ncdata.variables['lon'][:]
    sig=ncdata.variables['sigma'][:]
    var_=ncdata.variables[var_name][:]
    ncdata.close()
    var = np.zeros((np.shape(var_)))[np.newaxis, ...]
    for d_i, d in enumerate(np.arange(1,len(day_list))):
        ncdata = Dataset(fn%d,'r')
        var=np.append(var, (ncdata.variables[var_name][:])[np.newaxis, ...], axis = 0)
        ncdata.close()
    
    return zon_waven, legendre, lat, lon, sig, var


def append_year_days_zonal_mean(fn, day_list, eddy_stats = True, enable_print_ncinfo=False):
    ncdata =Dataset(fn%1,'r')
    if enable_print_ncinfo==True:
        print_ncinfo(ncdata)
    lat = ncdata.variables['lat'][:]
    lon = ncdata.variables['lon'][:]
    sig=ncdata.variables['sigma'][:]
    ncdata.close()
    v = np.zeros((len(day_list), len(sig), len(lat)))
    u = np.zeros((len(day_list), len(sig), len(lat)))
    T = np.zeros((len(day_list), len(sig), len(lat)))
    uv = np.zeros((len(day_list), len(sig), len(lat)))
    vT = np.zeros((len(day_list), len(sig), len(lat)))
    TT = np.zeros((len(day_list), len(sig), len(lat)))
    eke = np.zeros((len(day_list), len(sig), len(lat)))
    for d_i, d in enumerate(np.arange(1,len(day_list))):
        ncdata = Dataset(fn%d,'r')
        v[d_i,:,:]=np.mean(ncdata.variables['v'][:],axis=-1)
        u[d_i,:,:]=np.mean(ncdata.variables['u'][:],axis=-1)
        T[d_i,:,:]=np.mean(ncdata.variables['temp'][:],axis=-1)
        if eddy_stats ==True:
            vST = ncdata.variables['v'][:] - v[d_i,:,:,None]
            uST = ncdata.variables['u'][:] - u[d_i,:,:,None]           
            TST = ncdata.variables['temp'][:] - T[d_i,:,:,None]
            uv[d_i,:,:]=np.mean(uST*vST,axis=-1)
            vT[d_i,:,:]=np.mean(vST*TST,axis=-1)
            TT[d_i,:,:]=np.mean(TST*TST,axis=-1)
            eke[d_i,:,:]=np.mean(uST**2+vST**2,axis=-1)
        ncdata.close()
    
    return lat, lon, sig, v, u, T, uv, vT, TT, eke

# %% [markdown]
# # Zonal means

# %%
# dirs / fnames
day_list = np.arange(500,900)

exp_name = "hs_control_num_fourier_63_num_num_spherical_64_lon_max_192_lat_max_96_num_levels_30"
data_dir = "/central/scratch/elencz/caltech_fms_idealized/hs_control/%s/output/ppp_output/"%exp_name
fname = "day1000h00.segment%s.nc"

lat, lon, sig, v, u, T, uv, vT, TT, eke = append_year_days_zonal_mean(data_dir+fname, day_list)
# Out:
# lat --> long_name = latitude
# lat --> units = degree
# lon --> long_name = longitute
# lon --> units = degrees_east
# sigma --> long_name = sigma level
# sigma --> units = none
# theta --> long_name = potential temperature level
# theta --> units = Kelvin
# zon_waven --> long_name = zonal wavenumber
# zon_waven --> units = none
# legendre --> long_name = legendre wavenumber
# legendre --> units = none
# rhum_bin --> long_name = relative humidity bin
# rhum_bin --> units = none
# precip_bin --> long_name = precipitation bin
# precip_bin --> units = none
# times --> long_name = number of instants
# p --> long_name = Pressure on Sigma Levels
# p --> units = Pa
# p_var --> long_name = Pressure Variance on Sigma Levels
# p_var --> units = Pa.Pa
# p_sfc --> long_name = Surface Pressure
# p_sfc --> units = Pa
# p_var_sfc --> long_name = Surface Pressure Variance
# p_var_sfc --> units = Pa.Pa
# specific_vol --> long_name = Specific Volume
# specific_vol --> units = m.m.m/Kg
# u --> long_name = Zonal Wind
# u --> units = m/s
# u_var --> long_name = Zonal Wind Variance
# u_var --> units = m.m/s/s
# u_barotr_var --> long_name = Barotropic Zonal Wind Variance
# u_barotr_var --> units = m.m/s/s
# u_mrdnl_flux --> long_name = Meridional Zonal Wind Flux
# u_mrdnl_flux --> units = m.m/s/s
# u_vrtcl_flux --> long_name = Vertical Zonal Wind Flux
# u_vrtcl_flux --> units = m/s/s
# v --> long_name = Meridional Wind
# v --> units = m/s
# v_var --> long_name = Meridional Wind Variance
# v_var --> units = m.m/s/s
# vort --> long_name = Relative Vorticity
# vort --> units = 1/s
# vort_var --> long_name = Relative Vorticity Variance
# vort_var --> units = 1/s/s
# v_barotr_var --> long_name = Barotropic Meridional Wind Variance
# v_barotr_var --> units = m.m/s/s
# w --> long_name = Vertical Wind; w = \dot\sigma
# w --> units = 1/s
# w_var --> long_name = Vertical Wind Variance
# w_var --> units = 1/s/s
# streamfctn --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction
# streamfctn --> units = kg/s
# streamfctn_var --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction Variance
# streamfctn_var --> units = kg.kg/s/s
# streamfctn_TEM --> long_name = TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM --> units = kg/s
# streamfctn_TEM_modif --> long_name = Modified TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM_modif --> units = kg/s
# temp --> long_name = Temperature
# temp --> units = K
# temp_var --> long_name = Temperature Variance
# temp_var --> units = K.K
# temp_zonal_flux --> long_name = Zonal Temperature Flux
# temp_zonal_flux --> units = K.m/s
# temp_mrdnl_flux --> long_name = Meridional Temperature Flux
# temp_mrdnl_flux --> units = K.m/s
# temp_vrtcl_flux --> long_name = Vertical Temperature Flux
# temp_vrtcl_flux --> units = K/s
# z --> long_name = Geopotential Height
# z --> units = m
# z_var --> long_name = Geopotential Height Variance
# z_var --> units = m.m
# z_zonal_flux --> long_name = Zonal Geopotential Height Flux
# z_zonal_flux --> units = m.m/s
# z_mrdnl_flux --> long_name = Meridional Geopotential Height Flux
# z_mrdnl_flux --> units = m.m/s
# z_vrtcl_flux --> long_name = Vertical Geopotential Height Flux
# z_vrtcl_flux --> units = m/s
# pot_temp --> long_name = Potential Temperature
# pot_temp --> units = K
# pot_temp_var --> long_name = Potential Temperature Variance
# pot_temp_var --> units = K.K
# pot_temp_zonal_flux --> long_name = Zonal Potential Temperature Flux
# pot_temp_zonal_flux --> units = K.m/s
# pot_temp_mrdnl_flux --> long_name = Meridional Potential Temperature Flux
# pot_temp_mrdnl_flux --> units = K.m/s
# pot_temp_vrtcl_flux --> long_name = Vertical Potential Temperature_Flux
# pot_temp_vrtcl_flux --> units = K/s
# pot_temp_mrdnl_deriv --> long_name = Meridional Potential Temperature Gradient
# pot_temp_mrdnl_deriv --> units = K/m
# pot_temp_vrtcl_deriv --> long_name = Vertical Potential Temperature Gradient
# pot_temp_vrtcl_deriv --> units = K/Pa
# pot_temp_psd --> long_name = Potential Temperature Horizontal Power Spectral Density
# pot_temp_psd --> units = K.K
# buoyancy_freq --> long_name = Buoyancy Frequency
# buoyancy_freq --> units = 1/s
# buoyancy_freq --> _FillValue = -9e-14
# eape2eke_flux_psd --> long_name = EAPE to EKE Conversion Horizontal Power Spectral Density
# eape2eke_flux_psd --> units = K.m/s
# u_eddy_mrdnl_flux --> long_name = Meridional Eddy Zonal Wind Flux
# u_eddy_mrdnl_flux --> units = m.m/s/s
# u_eddy_vrtcl_flux --> long_name = Vertical Eddy Zonal Wind Flux
# u_eddy_vrtcl_flux --> units = m/s/s
# temp_eddy_zonal_flux --> long_name = Zonal Eddy Temperature Flux
# temp_eddy_zonal_flux --> units = K.m/s
# temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Temperature Flux
# temp_eddy_mrdnl_flux --> units = K.m/s
# temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Temperature Flux
# temp_eddy_vrtcl_flux --> units = K/s
# z_eddy_zonal_flux --> long_name = Zonal Eddy Geopotential Height Flux
# z_eddy_zonal_flux --> units = m.m/s
# z_eddy_mrdnl_flux --> long_name = Meridional Eddy Geopotential Height Flux
# z_eddy_mrdnl_flux --> units = m.m/s
# z_eddy_vrtcl_flux --> long_name = Vertical Eddy Geopotential Height Flux
# z_eddy_vrtcl_flux --> units = m/s
# pot_temp_eddy_zonal_flux --> long_name = Zonal Eddy Potential Temperature Flux
# pot_temp_eddy_zonal_flux --> units = K.m/s
# pot_temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Potential Temperature Flux
# pot_temp_eddy_mrdnl_flux --> units = K.m/s
# pot_temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Potential Temperature Flux
# pot_temp_eddy_vrtcl_flux --> units = K/s
# p_isent_nw --> long_name = Pressure
# p_isent_nw --> units = Pa
# p_var_isent_nw --> long_name = Pressure Variance
# p_var_isent_nw --> units = Pa.Pa
# exner_isent_nw --> long_name = Exner function
# exner_isent_nw --> units = J/kg/K
# p_exner_isent_nw --> long_name = Pressure * Exner function
# p_exner_isent_nw --> units = kg.m.m.m/s/s/s/s/K
# dens_isent_nw --> long_name = Isentropic Density
# dens_isent_nw --> units = kg/m/m/K
# u_isent --> long_name = Zonal Wind
# u_isent --> units = dens.m/s
# u_var_isent --> long_name = Zonal Wind Variance
# u_var_isent --> units = dens.m.m/s/s
# v_isent --> long_name = Meridional Wind
# v_isent --> units = dens.m/s
# v_var_isent --> long_name = Meridional Wind Variance
# v_var_isent --> units = dens.m.m/s/s
# v_geostr_isent --> long_name = Meridional Geostrophic Wind
# v_geostr_isent --> units = m/s
# streamfctn_isent --> long_name = Streamfunction
# streamfctn_isent --> units = kg/s
# pot_vor_isent --> long_name = Potential Vorticity
# pot_vor_isent --> units = 1/s/
# pot_vor_mrdnl_flux_isent --> long_name = Meridional Potential Vorticity Flux
# pot_vor_mrdnl_flux_isent --> units = m/s/s
# pot_vor_eddy_mrdnl_flux_isent --> long_name = Meridional Eddy Potential Vorticity Flux
# pot_vor_eddy_mrdnl_flux_isent --> units = m/s/s
# mont_isent --> long_name = Montgomery Function
# mont_isent --> units = dens.J/kg
# mont_var_isent --> long_name = Montgomery Function Variance
# mont_var_isent --> units = dens.J.J/kg/kg
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> long_name = Surface Geostrophic Eddy Potential Temperature Flux
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> units = K.m/s

# %%
# plotting helpers
def zonal_plot(lat, lev, var, title = '', subplot_no=(1,1,1)):
    a,b,c = subplot_no
    plt.subplot(a,b,c)
    f1 = plt.contourf(lat, lev, var)
    plt.colorbar(f1)
    plt.gca().invert_yaxis()
    plt.title(title)

# diagnostic helpers
def psi(V_xBAR,level_list_array,lat):
    _a, _g = (6371000., 9.81) # Earth_radius, grav_constant
    latrad = lat*np.pi/180.
    psi = _a/_g * 2. * np.pi * np.cos(latrad)[None,None,:] * integrate.cumtrapz(V_xBAR,level_list_array,axis = 1)
    return psi

# %%
# Viz zonal means

# U, T, meridional streamfunctions
plt.figure(figsize=(12,4))
zonal_plot(lat, sig, np.mean(u,axis=0), title = 'U', subplot_no = (1,3,1))
zonal_plot(lat, sig, np.mean(T,axis=0), title = 'T', subplot_no = (1,3,2))
zonal_plot(lat, sig[:-1], np.mean(psi(v,sig,lat),axis=0), title = 'meridional streamfunction', subplot_no = (1,3,3))

# vT, uv, u^2+v^2, TT
plt.figure(figsize=(16,4))
zonal_plot(lat, sig, np.mean(vT,axis=0), title = 'vT', subplot_no = (1,4,1))
zonal_plot(lat, sig, np.mean(eke,axis=0), title = 'eke', subplot_no = (1,4,2))
zonal_plot(lat, sig, np.mean(uv,axis=0), title = 'uv', subplot_no = (1,4,3))
zonal_plot(lat, sig, np.mean(TT,axis=0), title = 'TT', subplot_no = (1,4,4))

print(exp_name)
# Out:
# hs_control_num_fourier_63_num_num_spherical_64_lon_max_192_lat_max_96_num_levels_30

# %% [markdown]
# # Spectral

# %%
# spectral info
zonal_wn, legendre, lat, lon, sig, var = append_year_days_onevar(data_dir+fname, day_list, 'pot_temp_psd') #flipped (zon_wavenDimID, legendreDimID, sigmaDimID)
# Out:
# lat --> long_name = latitude
# lat --> units = degree
# lon --> long_name = longitute
# lon --> units = degrees_east
# sigma --> long_name = sigma level
# sigma --> units = none
# theta --> long_name = potential temperature level
# theta --> units = Kelvin
# zon_waven --> long_name = zonal wavenumber
# zon_waven --> units = none
# legendre --> long_name = legendre wavenumber
# legendre --> units = none
# rhum_bin --> long_name = relative humidity bin
# rhum_bin --> units = none
# precip_bin --> long_name = precipitation bin
# precip_bin --> units = none
# times --> long_name = number of instants
# p --> long_name = Pressure on Sigma Levels
# p --> units = Pa
# p_var --> long_name = Pressure Variance on Sigma Levels
# p_var --> units = Pa.Pa
# p_sfc --> long_name = Surface Pressure
# p_sfc --> units = Pa
# p_var_sfc --> long_name = Surface Pressure Variance
# p_var_sfc --> units = Pa.Pa
# specific_vol --> long_name = Specific Volume
# specific_vol --> units = m.m.m/Kg
# u --> long_name = Zonal Wind
# u --> units = m/s
# u_var --> long_name = Zonal Wind Variance
# u_var --> units = m.m/s/s
# u_barotr_var --> long_name = Barotropic Zonal Wind Variance
# u_barotr_var --> units = m.m/s/s
# u_mrdnl_flux --> long_name = Meridional Zonal Wind Flux
# u_mrdnl_flux --> units = m.m/s/s
# u_vrtcl_flux --> long_name = Vertical Zonal Wind Flux
# u_vrtcl_flux --> units = m/s/s
# v --> long_name = Meridional Wind
# v --> units = m/s
# v_var --> long_name = Meridional Wind Variance
# v_var --> units = m.m/s/s
# vort --> long_name = Relative Vorticity
# vort --> units = 1/s
# vort_var --> long_name = Relative Vorticity Variance
# vort_var --> units = 1/s/s
# v_barotr_var --> long_name = Barotropic Meridional Wind Variance
# v_barotr_var --> units = m.m/s/s
# w --> long_name = Vertical Wind; w = \dot\sigma
# w --> units = 1/s
# w_var --> long_name = Vertical Wind Variance
# w_var --> units = 1/s/s
# streamfctn --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction
# streamfctn --> units = kg/s
# streamfctn_var --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction Variance
# streamfctn_var --> units = kg.kg/s/s
# streamfctn_TEM --> long_name = TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM --> units = kg/s
# streamfctn_TEM_modif --> long_name = Modified TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM_modif --> units = kg/s
# temp --> long_name = Temperature
# temp --> units = K
# temp_var --> long_name = Temperature Variance
# temp_var --> units = K.K
# temp_zonal_flux --> long_name = Zonal Temperature Flux
# temp_zonal_flux --> units = K.m/s
# temp_mrdnl_flux --> long_name = Meridional Temperature Flux
# temp_mrdnl_flux --> units = K.m/s
# temp_vrtcl_flux --> long_name = Vertical Temperature Flux
# temp_vrtcl_flux --> units = K/s
# z --> long_name = Geopotential Height
# z --> units = m
# z_var --> long_name = Geopotential Height Variance
# z_var --> units = m.m
# z_zonal_flux --> long_name = Zonal Geopotential Height Flux
# z_zonal_flux --> units = m.m/s
# z_mrdnl_flux --> long_name = Meridional Geopotential Height Flux
# z_mrdnl_flux --> units = m.m/s
# z_vrtcl_flux --> long_name = Vertical Geopotential Height Flux
# z_vrtcl_flux --> units = m/s
# pot_temp --> long_name = Potential Temperature
# pot_temp --> units = K
# pot_temp_var --> long_name = Potential Temperature Variance
# pot_temp_var --> units = K.K
# pot_temp_zonal_flux --> long_name = Zonal Potential Temperature Flux
# pot_temp_zonal_flux --> units = K.m/s
# pot_temp_mrdnl_flux --> long_name = Meridional Potential Temperature Flux
# pot_temp_mrdnl_flux --> units = K.m/s
# pot_temp_vrtcl_flux --> long_name = Vertical Potential Temperature_Flux
# pot_temp_vrtcl_flux --> units = K/s
# pot_temp_mrdnl_deriv --> long_name = Meridional Potential Temperature Gradient
# pot_temp_mrdnl_deriv --> units = K/m
# pot_temp_vrtcl_deriv --> long_name = Vertical Potential Temperature Gradient
# pot_temp_vrtcl_deriv --> units = K/Pa
# pot_temp_psd --> long_name = Potential Temperature Horizontal Power Spectral Density
# pot_temp_psd --> units = K.K
# buoyancy_freq --> long_name = Buoyancy Frequency
# buoyancy_freq --> units = 1/s
# buoyancy_freq --> _FillValue = -9e-14
# eape2eke_flux_psd --> long_name = EAPE to EKE Conversion Horizontal Power Spectral Density
# eape2eke_flux_psd --> units = K.m/s
# u_eddy_mrdnl_flux --> long_name = Meridional Eddy Zonal Wind Flux
# u_eddy_mrdnl_flux --> units = m.m/s/s
# u_eddy_vrtcl_flux --> long_name = Vertical Eddy Zonal Wind Flux
# u_eddy_vrtcl_flux --> units = m/s/s
# temp_eddy_zonal_flux --> long_name = Zonal Eddy Temperature Flux
# temp_eddy_zonal_flux --> units = K.m/s
# temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Temperature Flux
# temp_eddy_mrdnl_flux --> units = K.m/s
# temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Temperature Flux
# temp_eddy_vrtcl_flux --> units = K/s
# z_eddy_zonal_flux --> long_name = Zonal Eddy Geopotential Height Flux
# z_eddy_zonal_flux --> units = m.m/s
# z_eddy_mrdnl_flux --> long_name = Meridional Eddy Geopotential Height Flux
# z_eddy_mrdnl_flux --> units = m.m/s
# z_eddy_vrtcl_flux --> long_name = Vertical Eddy Geopotential Height Flux
# z_eddy_vrtcl_flux --> units = m/s
# pot_temp_eddy_zonal_flux --> long_name = Zonal Eddy Potential Temperature Flux
# pot_temp_eddy_zonal_flux --> units = K.m/s
# pot_temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Potential Temperature Flux
# pot_temp_eddy_mrdnl_flux --> units = K.m/s
# pot_temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Potential Temperature Flux
# pot_temp_eddy_vrtcl_flux --> units = K/s
# p_isent_nw --> long_name = Pressure
# p_isent_nw --> units = Pa
# p_var_isent_nw --> long_name = Pressure Variance
# p_var_isent_nw --> units = Pa.Pa
# exner_isent_nw --> long_name = Exner function
# exner_isent_nw --> units = J/kg/K
# p_exner_isent_nw --> long_name = Pressure * Exner function
# p_exner_isent_nw --> units = kg.m.m.m/s/s/s/s/K
# dens_isent_nw --> long_name = Isentropic Density
# dens_isent_nw --> units = kg/m/m/K
# u_isent --> long_name = Zonal Wind
# u_isent --> units = dens.m/s
# u_var_isent --> long_name = Zonal Wind Variance
# u_var_isent --> units = dens.m.m/s/s
# v_isent --> long_name = Meridional Wind
# v_isent --> units = dens.m/s
# v_var_isent --> long_name = Meridional Wind Variance
# v_var_isent --> units = dens.m.m/s/s
# v_geostr_isent --> long_name = Meridional Geostrophic Wind
# v_geostr_isent --> units = m/s
# streamfctn_isent --> long_name = Streamfunction
# streamfctn_isent --> units = kg/s
# pot_vor_isent --> long_name = Potential Vorticity
# pot_vor_isent --> units = 1/s/
# pot_vor_mrdnl_flux_isent --> long_name = Meridional Potential Vorticity Flux
# pot_vor_mrdnl_flux_isent --> units = m/s/s
# pot_vor_eddy_mrdnl_flux_isent --> long_name = Meridional Eddy Potential Vorticity Flux
# pot_vor_eddy_mrdnl_flux_isent --> units = m/s/s
# mont_isent --> long_name = Montgomery Function
# mont_isent --> units = dens.J/kg
# mont_var_isent --> long_name = Montgomery Function Variance
# mont_var_isent --> units = dens.J.J/kg/kg
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> long_name = Surface Geostrophic Eddy Potential Temperature Flux
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> units = K.m/s

# %%
print(np.shape(var))

sig_i500 = [i for i,x in enumerate(sig) if ((x > 0.7) & (x < 0.8))][0]
f1 = plt.contourf(legendre, zonal_wn, np.log(np.mean(var,axis=0)[sig_i500,:,:]))#, np.arange(-10e-2, 10e-2, 10e-3))
plt.colorbar(f1)
# Out:
# (400, 30, 64, 64)
# /central/home/elencz/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
plt.plot(zonal_wn[1:],np.mean(var[:,sig_i500,1:,:],axis=(0,-1)))

# %%
plt.plot(zonal_wn[1:],np.mean(var[1:,sig_i500,:,1:],axis=(0,-2)))
plt.xlabel("zonal wn")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# # Horizontal animation

# %%
# Viz animation

zonal_wn, legendre, lat, lon, sig, u = append_year_days_onevar(data_dir+fname, day_list, 'u')
# Out:
# lat --> long_name = latitude
# lat --> units = degree
# lon --> long_name = longitute
# lon --> units = degrees_east
# sigma --> long_name = sigma level
# sigma --> units = none
# theta --> long_name = potential temperature level
# theta --> units = Kelvin
# zon_waven --> long_name = zonal wavenumber
# zon_waven --> units = none
# legendre --> long_name = legendre wavenumber
# legendre --> units = none
# rhum_bin --> long_name = relative humidity bin
# rhum_bin --> units = none
# precip_bin --> long_name = precipitation bin
# precip_bin --> units = none
# times --> long_name = number of instants
# p --> long_name = Pressure on Sigma Levels
# p --> units = Pa
# p_var --> long_name = Pressure Variance on Sigma Levels
# p_var --> units = Pa.Pa
# p_sfc --> long_name = Surface Pressure
# p_sfc --> units = Pa
# p_var_sfc --> long_name = Surface Pressure Variance
# p_var_sfc --> units = Pa.Pa
# specific_vol --> long_name = Specific Volume
# specific_vol --> units = m.m.m/Kg
# u --> long_name = Zonal Wind
# u --> units = m/s
# u_var --> long_name = Zonal Wind Variance
# u_var --> units = m.m/s/s
# u_barotr_var --> long_name = Barotropic Zonal Wind Variance
# u_barotr_var --> units = m.m/s/s
# u_mrdnl_flux --> long_name = Meridional Zonal Wind Flux
# u_mrdnl_flux --> units = m.m/s/s
# u_vrtcl_flux --> long_name = Vertical Zonal Wind Flux
# u_vrtcl_flux --> units = m/s/s
# v --> long_name = Meridional Wind
# v --> units = m/s
# v_var --> long_name = Meridional Wind Variance
# v_var --> units = m.m/s/s
# vort --> long_name = Relative Vorticity
# vort --> units = 1/s
# vort_var --> long_name = Relative Vorticity Variance
# vort_var --> units = 1/s/s
# v_barotr_var --> long_name = Barotropic Meridional Wind Variance
# v_barotr_var --> units = m.m/s/s
# w --> long_name = Vertical Wind; w = \dot\sigma
# w --> units = 1/s
# w_var --> long_name = Vertical Wind Variance
# w_var --> units = 1/s/s
# streamfctn --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction
# streamfctn --> units = kg/s
# streamfctn_var --> long_name = Eulerian-Mean Meridional Mass Flux Streamfunction Variance
# streamfctn_var --> units = kg.kg/s/s
# streamfctn_TEM --> long_name = TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM --> units = kg/s
# streamfctn_TEM_modif --> long_name = Modified TE-Mean Meridional Mass Flux Streamfunction
# streamfctn_TEM_modif --> units = kg/s
# temp --> long_name = Temperature
# temp --> units = K
# temp_var --> long_name = Temperature Variance
# temp_var --> units = K.K
# temp_zonal_flux --> long_name = Zonal Temperature Flux
# temp_zonal_flux --> units = K.m/s
# temp_mrdnl_flux --> long_name = Meridional Temperature Flux
# temp_mrdnl_flux --> units = K.m/s
# temp_vrtcl_flux --> long_name = Vertical Temperature Flux
# temp_vrtcl_flux --> units = K/s
# z --> long_name = Geopotential Height
# z --> units = m
# z_var --> long_name = Geopotential Height Variance
# z_var --> units = m.m
# z_zonal_flux --> long_name = Zonal Geopotential Height Flux
# z_zonal_flux --> units = m.m/s
# z_mrdnl_flux --> long_name = Meridional Geopotential Height Flux
# z_mrdnl_flux --> units = m.m/s
# z_vrtcl_flux --> long_name = Vertical Geopotential Height Flux
# z_vrtcl_flux --> units = m/s
# pot_temp --> long_name = Potential Temperature
# pot_temp --> units = K
# pot_temp_var --> long_name = Potential Temperature Variance
# pot_temp_var --> units = K.K
# pot_temp_zonal_flux --> long_name = Zonal Potential Temperature Flux
# pot_temp_zonal_flux --> units = K.m/s
# pot_temp_mrdnl_flux --> long_name = Meridional Potential Temperature Flux
# pot_temp_mrdnl_flux --> units = K.m/s
# pot_temp_vrtcl_flux --> long_name = Vertical Potential Temperature_Flux
# pot_temp_vrtcl_flux --> units = K/s
# pot_temp_mrdnl_deriv --> long_name = Meridional Potential Temperature Gradient
# pot_temp_mrdnl_deriv --> units = K/m
# pot_temp_vrtcl_deriv --> long_name = Vertical Potential Temperature Gradient
# pot_temp_vrtcl_deriv --> units = K/Pa
# pot_temp_psd --> long_name = Potential Temperature Horizontal Power Spectral Density
# pot_temp_psd --> units = K.K
# buoyancy_freq --> long_name = Buoyancy Frequency
# buoyancy_freq --> units = 1/s
# buoyancy_freq --> _FillValue = -9e-14
# eape2eke_flux_psd --> long_name = EAPE to EKE Conversion Horizontal Power Spectral Density
# eape2eke_flux_psd --> units = K.m/s
# u_eddy_mrdnl_flux --> long_name = Meridional Eddy Zonal Wind Flux
# u_eddy_mrdnl_flux --> units = m.m/s/s
# u_eddy_vrtcl_flux --> long_name = Vertical Eddy Zonal Wind Flux
# u_eddy_vrtcl_flux --> units = m/s/s
# temp_eddy_zonal_flux --> long_name = Zonal Eddy Temperature Flux
# temp_eddy_zonal_flux --> units = K.m/s
# temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Temperature Flux
# temp_eddy_mrdnl_flux --> units = K.m/s
# temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Temperature Flux
# temp_eddy_vrtcl_flux --> units = K/s
# z_eddy_zonal_flux --> long_name = Zonal Eddy Geopotential Height Flux
# z_eddy_zonal_flux --> units = m.m/s
# z_eddy_mrdnl_flux --> long_name = Meridional Eddy Geopotential Height Flux
# z_eddy_mrdnl_flux --> units = m.m/s
# z_eddy_vrtcl_flux --> long_name = Vertical Eddy Geopotential Height Flux
# z_eddy_vrtcl_flux --> units = m/s
# pot_temp_eddy_zonal_flux --> long_name = Zonal Eddy Potential Temperature Flux
# pot_temp_eddy_zonal_flux --> units = K.m/s
# pot_temp_eddy_mrdnl_flux --> long_name = Meridional Eddy Potential Temperature Flux
# pot_temp_eddy_mrdnl_flux --> units = K.m/s
# pot_temp_eddy_vrtcl_flux --> long_name = Vertical Eddy Potential Temperature Flux
# pot_temp_eddy_vrtcl_flux --> units = K/s
# p_isent_nw --> long_name = Pressure
# p_isent_nw --> units = Pa
# p_var_isent_nw --> long_name = Pressure Variance
# p_var_isent_nw --> units = Pa.Pa
# exner_isent_nw --> long_name = Exner function
# exner_isent_nw --> units = J/kg/K
# p_exner_isent_nw --> long_name = Pressure * Exner function
# p_exner_isent_nw --> units = kg.m.m.m/s/s/s/s/K
# dens_isent_nw --> long_name = Isentropic Density
# dens_isent_nw --> units = kg/m/m/K
# u_isent --> long_name = Zonal Wind
# u_isent --> units = dens.m/s
# u_var_isent --> long_name = Zonal Wind Variance
# u_var_isent --> units = dens.m.m/s/s
# v_isent --> long_name = Meridional Wind
# v_isent --> units = dens.m/s
# v_var_isent --> long_name = Meridional Wind Variance
# v_var_isent --> units = dens.m.m/s/s
# v_geostr_isent --> long_name = Meridional Geostrophic Wind
# v_geostr_isent --> units = m/s
# streamfctn_isent --> long_name = Streamfunction
# streamfctn_isent --> units = kg/s
# pot_vor_isent --> long_name = Potential Vorticity
# pot_vor_isent --> units = 1/s/
# pot_vor_mrdnl_flux_isent --> long_name = Meridional Potential Vorticity Flux
# pot_vor_mrdnl_flux_isent --> units = m/s/s
# pot_vor_eddy_mrdnl_flux_isent --> long_name = Meridional Eddy Potential Vorticity Flux
# pot_vor_eddy_mrdnl_flux_isent --> units = m/s/s
# mont_isent --> long_name = Montgomery Function
# mont_isent --> units = dens.J/kg
# mont_var_isent --> long_name = Montgomery Function Variance
# mont_var_isent --> units = dens.J.J/kg/kg
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> long_name = Surface Geostrophic Eddy Potential Temperature Flux
# pot_temp_geostr_eddy_mrdnl_flux_sfc --> units = K.m/s

# %%
plt.contourf(lon, lat, (u[1,sig_i500,:,:]))
from IPython.display import HTML

# %%
#%matplotlib notebook
from matplotlib import animation, rc
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

sig_i700 = [i for i,x in enumerate(sig) if ((x > 0.7) & (x < 0.8))][0]


plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

fig, ax = plt.subplots()
f1 = ax.contourf(lon, lat, u[0,sig_i700,:,:],np.arange(-30,30,1))
plt.colorbar(f1)

def animate(frame_num):
    ax.clear()
    ax.contourf(lon, lat, u[frame_num,sig_i700,:,:],np.arange(-30,30,1))
    ax.set_title('%03d'%frame_num) 
    return ax
    
anim = animation.FuncAnimation(fig, animate, 300, interval=50, blit=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
