# %% [markdown]
# # Analyze UF sensitivity runs
#
# ## pre-reqs
# - py3.9

# %% [markdown]
# ## Setting up the experiments
# - runfolder: `exp/uf_tests_hpc`
# - run script: `exp/uf_tests_hpc/run/run_exp`
#     - adapt parameters in namelists
#     - runtime info
#         work_dir   = /central/scratch/elencz/caltech_fms_idealized/$exp_name/$run_name/workdir
#         output_dir = /central/scratch/elencz/caltech_fms_idealized/$exp_name/$run_name/output
#
#     - diagnostics
#         diagtable = $exp_home/input/diag_table_${model_type}_${analysis_type}
#         raw_output = $work_dir/*.nc
#         combined_output = $output_dir/combine/$date_name/$date_name.$ncfile
#
# - current setup:
#     - 5 years
#     - T85 (see exp/uf_tests_hpc/input/namelists_moist)

# %%
# var_save_dir = "/central/scratch/elencz/caltech_fms_idealized/slab_syn_diff/analysis/"

# %%
#modules
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from scipy import integrate
import h5py as h5
from scipy import ndimage

# global parameters:
_a = 6371000.0
_g = 9.81

# %%
# read in data_helper.py
exec(open("../helpers/data_helper.py").read())

# %%
# control run
exp_name = "uf_tests_hpc_businger_albedo"
run_name = "uf_tests_hpc_businger_albedo_albedo02rcrit15_0"
work_dir = "/central/scratch/elencz/caltech_fms_idealized/%s/%s/workdir"%(exp_name, run_name)
output_dir = "/central/scratch/elencz/caltech_fms_idealized/%s/%s/output"%(exp_name, run_name)

ppp_dir = output_dir + "/ppp_output/"

fname = "day%sh00.segment%s.nc"


day_list = np.arange(1,361)
last_day_of_yr = "1440"# "%04d"%day_list[-1]

lat, lon, sig, v, u, T, Th, uv, vT, TT, eke, u_vrtcl_flux, pot_temp_vrtcl_flux, z1, T1, lh_flux_sfc, sh_flux_sfc, T_sfc = append_year_days_zonal_mean(ppp_dir+fname%(last_day_of_yr, "%s"), day_list)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1411         lst = repr(arr.item())
#    1412     elif arr.size > 0 or arr.shape == (0,):
# -> 1413         lst = array2string(arr, max_line_width, precision, suppress_small,
#    1414                            ', ', prefix, suffix=suffix)
#    1415     else:  # show zero-length shape unless it is (0,)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     690         return "[]"
#     691
# --> 692     return _array2string(a, options, separator, prefix)
#     693
#     694
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in wrapper(self, *args, **kwargs)
#     466             repr_running.add(key)
#     467             try:
# --> 468                 return f(self, *args, **kwargs)
#     469             finally:
#     470                 repr_running.discard(key)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _array2string(a, options, separator, prefix)
#     487     if a.size > options['threshold']:
#     488         summary_insert = "..."
# --> 489         data = _leading_trailing(data, options['edgeitems'])
#     490     else:
#     491         summary_insert = ""
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _leading_trailing(a, edgeitems, index)
#     335     if a.shape[axis] > 2*edgeitems:
#     336         return concatenate((
# --> 337             _leading_trailing(a, edgeitems, index + np.index_exp[ :edgeitems]),
#     338             _leading_trailing(a, edgeitems, index + np.index_exp[-edgeitems:])
#     339         ), axis=axis)
#
# AttributeError: module 'numpy' has no attribute 'index_exp'

# %%
# plotting helpers
def zonal_plot(lat, lev, var, title = '', subplot_no=(1,1,1), vrange = 20):
    a,b,c = subplot_no
    plt.subplot(a,b,c)
    f1 = plt.contourf(lat, lev, var, vrange)
    plt.colorbar(f1)
    plt.gca().invert_yaxis()
    plt.title(title)

# diagnostic helpers
def psi(V_xBAR,level_list_array,lat):
    _a, _g = (6371000. , 9.81) # Earth_radius, grav_constant
    latrad = lat*np.pi/180.
    psi = _a/_g * 2. * np.pi * np.cos(latrad)[None,None,:] * integrate.cumtrapz(V_xBAR,level_list_array,axis = 1)
    return psi

# %%
u
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1411         lst = repr(arr.item())
#    1412     elif arr.size > 0 or arr.shape == (0,):
# -> 1413         lst = array2string(arr, max_line_width, precision, suppress_small,
#    1414                            ', ', prefix, suffix=suffix)
#    1415     else:  # show zero-length shape unless it is (0,)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     690         return "[]"
#     691
# --> 692     return _array2string(a, options, separator, prefix)
#     693
#     694
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in wrapper(self, *args, **kwargs)
#     466             repr_running.add(key)
#     467             try:
# --> 468                 return f(self, *args, **kwargs)
#     469             finally:
#     470                 repr_running.discard(key)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _array2string(a, options, separator, prefix)
#     487     if a.size > options['threshold']:
#     488         summary_insert = "..."
# --> 489         data = _leading_trailing(data, options['edgeitems'])
#     490     else:
#     491         summary_insert = ""
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/arrayprint.py in _leading_trailing(a, edgeitems, index)
#     335     if a.shape[axis] > 2*edgeitems:
#     336         return concatenate((
# --> 337             _leading_trailing(a, edgeitems, index + np.index_exp[ :edgeitems]),
#     338             _leading_trailing(a, edgeitems, index + np.index_exp[-edgeitems:])
#     339         ), axis=axis)
#
# AttributeError: module 'numpy' has no attribute 'index_exp'

# %%
# U, T, meridional streamfunctions
plt.figure(figsize=(20,4))
zonal_plot(lat, sig, np.mean(u,axis=0), title = 'U', subplot_no = (1,4,1), vrange = np.arange(-32,33,4))
zonal_plot(lat, sig, np.mean(T,axis=0), title = 'T', subplot_no = (1,4,2), vrange = np.arange(170,330,10))
zonal_plot(lat, sig, np.mean(TT,axis=0), title = 'TT', subplot_no = (1,4,3), vrange = np.arange(-32,41,8))
pressure = sig * 100000.0 # units: Pa
zonal_plot(lat, sig[:-1], np.mean(psi(v, pressure ,lat),axis=0), title = 'meridional streamfunction', subplot_no = (1,4,4), vrange = np.arange(-8.8e10,8.9e10,0.8e10))

# vT, uv, u^2+v^2, TT
plt.figure(figsize=(20,4))
zonal_plot(lat, sig, np.mean(uv,axis=0), title = 'uv', subplot_no = (1,4,1) , vrange = np.arange(-66,67,6))
zonal_plot(lat, sig, np.mean(vT,axis=0), title = 'vT', subplot_no = (1,4,2) , vrange = np.arange(-18,19,2))
zonal_plot(lat, sig, np.mean(0.5*eke,axis=0), title = 'eke', subplot_no = (1,4,3), vrange = np.arange(0,330,15))

# turbulent surface fluxes
plt.figure(figsize=(20,4))
zonal_plot(lon, lat, (np.mean(lh_flux_sfc,axis=0)), title = 'latent (W/m2)', subplot_no = (1,4,1) , vrange = np.arange(-150,151,5))
zonal_plot(lon, lat, np.mean(sh_flux_sfc,axis=0), title = 'sensible (W/m2)', subplot_no = (1,4,2) , vrange = np.arange(-150,151,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_58948/242756366.py in <module>
#       1 # U, T, meridional streamfunctions
#       2 plt.figure(figsize=(20,4))
# ----> 3 zonal_plot(lat, sig, np.mean(u,axis=0), title = 'U', subplot_no = (1,4,1), vrange = np.arange(-32,33,4))
#       4 zonal_plot(lat, sig, np.mean(T,axis=0), title = 'T', subplot_no = (1,4,2), vrange = np.arange(170,330,10))
#       5 zonal_plot(lat, sig, np.mean(TT,axis=0), title = 'TT', subplot_no = (1,4,3), vrange = np.arange(-32,41,8))
#
# /tmp/ipykernel_58948/3988237870.py in zonal_plot(lat, lev, var, title, subplot_no, vrange)
#       3     a,b,c = subplot_no
#       4     plt.subplot(a,b,c)
# ----> 5     f1 = plt.contourf(lat, lev, var, vrange)
#       6     plt.colorbar(f1)
#       7     plt.gca().invert_yaxis()
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2480 @_copy_docstring_and_deprecators(Axes.contourf)
#    2481 def contourf(*args, data=None, **kwargs):
# -> 2482     __ret = gca().contourf(
#    2483         *args, **({"data": data} if data is not None else {}),
#    2484         **kwargs)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6269         """
#    6270         kwargs['filled'] = True
# -> 6271         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6272         self._request_autoscale_view()
#    6273         return contours
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     918             col.sticky_edges.y[:] = [self._mins[1], self._maxs[1]]
#     919         self.axes.update_datalim([self._mins, self._maxs])
# --> 920         self.axes.autoscale_view(tight=True)
#     921
#     922         self.changed()  # set the colors
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2930             # End of definition of internal function 'handle_single_axis'.
#    2931
# -> 2932         handle_single_axis(
#    2933             scalex, self._autoscaleXon, self._shared_axes["x"], 'x',
#    2934             self.xaxis, self._xmargin, x_stickies, self.set_xbound)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/matplotlib/axes/_base.py in handle_single_axis(scale, autoscaleon, shared_axes, name, axis, margin, stickies, set_bound)
#    2881                 minimum_minpos = min(minimum_minpos,
#    2882                                      getattr(ax.dataLim, f"minpos{name}"))
# -> 2883             x_values = np.extract(np.isfinite(x_values), x_values)
#    2884             if x_values.size >= 1:
#    2885                 x0, x1 = (x_values.min(), x_values.max())
#
# <__array_function__ internals> in extract(*args, **kwargs)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/lib/function_base.py in extract(condition, arr)
#    1698
#    1699     """
# -> 1700     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#    1701
#    1702
#
# <__array_function__ internals> in ravel(*args, **kwargs)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py in ravel(a, order)
#    1815
#    1816     """
# -> 1817     if isinstance(a, np.matrix):
#    1818         return asarray(a).ravel(order=order)
#    1819     else:
#
# AttributeError: module 'numpy' has no attribute 'matrix'

# %%
lmo = (u_vrtcl_flux[-1,:,:] / pot_temp_vrtcl_flux[-1,:,:]  / 0.4 * T1[-1,:,:])
zeta = z1[-1,:,:]/ lmo
# Out:
# 34304.375267824726

# %%
# hist of zeta

plt.subplot(2,1,1)
c = plt.contourf(lon, lat, zeta, np.arange(-100,100,1))
plt.colorbar(c)
plt.subplot(2,1,2)
hist = plt.hist(zeta.flatten(), bins = np.arange(-100,100,1))
plt.xlabel('$\zeta$')
# Out:
# Text(0.5, 0, '$\\zeta$')

# %%
np.extrema(lmo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_84145/37011489.py in <module>
# ----> 1 np.extrema(lmo)
#
# ~/anaconda2/envs/py39/lib/python3.9/site-packages/numpy/__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'extrema'

# %%
# stationary waves ...

# %%
sig
# Out:
# masked_array(data=[0.004601  , 0.01082207, 0.01454894, 0.01936511,
#                    0.02551974, 0.03329663, 0.04301224, 0.05501126,
#                    0.06965926, 0.0873321 , 0.10840185, 0.13321935,
#                    0.16209355, 0.19526839, 0.23289812, 0.27502227,
#                    0.32154191, 0.37219895, 0.42656043, 0.48400947,
#                    0.54374468, 0.60478926, 0.66601038, 0.72614911,
#                    0.78386003, 0.83775905, 0.88647735, 0.92871842,
#                    0.96331513, 0.98928317],
#              mask=False,
#        fill_value=1e+20)

# %%
# businger run
exp_name = "uf_tests_hpc_businger"
run_name = "uf_tests_hpc_businger_ctrl_10"
work_dir = "/central/scratch/elencz/caltech_fms_idealized/%s/%s/workdir"%(exp_name, run_name)
output_dir = "/central/scratch/elencz/caltech_fms_idealized/%s/%s/output"%(exp_name, run_name)

ppp_dir = output_dir + "/ppp_output/"

fname = "day%sh00.segment%s.nc"


day_list = np.arange(1,361)
last_day_of_yr = "1440"# "%04d"%day_list[-1]

lat, lon, sig, v_b, u_b, T_b, Th_b, uv_b, vT_b, TT_b, eke_b, u_vrtcl_flux_b, pot_temp_vrtcl_flux_b, z1_b, T1_b, lh_flux_sfc_b, sh_flux_sfc_b, T_sfc_b = append_year_days_zonal_mean(ppp_dir+fname%(last_day_of_yr, "%s"), day_list)

# %%
# U, T, meridional streamfunctions
plt.figure(figsize=(20,4))
zonal_plot(lat, sig, np.mean(u,axis=0) - np.mean(u_b,axis=0), title = 'U', subplot_no = (1,4,1)) #, vrange = np.arange(-32,33,4))
zonal_plot(lat, sig, np.mean(T,axis=0) - np.mean(T_b,axis=0), title = 'T', subplot_no = (1,4,2)) #, vrange = np.arange(170,330,10))
zonal_plot(lat, sig, np.mean(TT,axis=0) - np.mean(TT_b,axis=0), title = 'TT', subplot_no = (1,4,3)) #, vrange = np.arange(-32,41,8))
pressure = sig * 100000.0 # units: Pa
zonal_plot(lat, sig[:-1], np.mean(psi(v, pressure ,lat),axis=0) - np.mean(psi(v_b, pressure ,lat),axis=0), title = 'meridional streamfunction', subplot_no = (1,4,4)) #, vrange = np.arange(-8.8e10,8.9e10,0.8e10))

# vT, uv, u^2+v^2, TT
plt.figure(figsize=(20,4))
zonal_plot(lat, sig, np.mean(uv,axis=0) - np.mean(uv_b,axis=0), title = 'uv', subplot_no = (1,4,1) ) #, vrange = np.arange(-66,67,6))
zonal_plot(lat, sig, np.mean(vT,axis=0) - np.mean(vT_b,axis=0), title = 'vT', subplot_no = (1,4,2) ) #, vrange = np.arange(-18,19,2))
zonal_plot(lat, sig, np.mean(0.5*eke,axis=0) - np.mean(0.5*eke_b,axis=0), title = 'eke', subplot_no = (1,4,3)) #, vrange = np.arange(0,330,15))

# turbulent surface fluxes
plt.figure(figsize=(8,8))
plt.subplot(211)
plt.plot(lat, np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0,-1)) , label = "lh")#, vrange = np.arange(-66,67,6))
plt.plot(lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0,-1)) , label = "sh" )#, vrange = np.arange(-18,19,2))
plt.plot(lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0,-1)) +np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0,-1)), "k", label = "sum" )#, vrange = np.arange(-18,19,2))
plt.plot(lat, np.mean(sh_flux_sfc + lh_flux_sfc,axis=(0,-1)), "0.5", label = "abs" )#, vrange = np.arange(-18,19,2))

plt.legend()
plt.xlabel("latitude (deg N)")
plt.ylabel("surface flux (W/m2)")


# turbulent surface fluxes
plt.figure(figsize=(8,8))
plt.subplot(311)
c = plt.contourf(lon, lat, np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0)) , label = "lh")#, vrange = np.arange(-66,67,6))
cb = plt.colorbar(c)
plt.ylabel("latitude (deg N)")
plt.title("lh")
plt.subplot(312)
c = plt.contourf(lon, lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0)) , label = "sh" )#, vrange = np.arange(-18,19,2))
cb = plt.colorbar(c)
plt.ylabel("latitude (deg N)")
plt.title("sh")
plt.subplot(313)
c = plt.contourf(lon, lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0)) +np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0)), label = "sum" )#, vrange = np.arange(-18,19,2))
cb = plt.colorbar(c)
plt.ylabel("latitude (deg N)")
plt.title("sum")
plt.xlabel("longitude (deg W)")
# Out:
# /tmp/ipykernel_84145/2159153768.py:31: UserWarning: The following kwargs were not used by contour: 'label'
#   c = plt.contourf(lon, lat, np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0)) , label = "lh")#, vrange = np.arange(-66,67,6))
# /tmp/ipykernel_84145/2159153768.py:36: UserWarning: The following kwargs were not used by contour: 'label'
#   c = plt.contourf(lon, lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0)) , label = "sh" )#, vrange = np.arange(-18,19,2))
# /tmp/ipykernel_84145/2159153768.py:41: UserWarning: The following kwargs were not used by contour: 'label'
#   c = plt.contourf(lon, lat, np.mean(sh_flux_sfc - sh_flux_sfc_b,axis=(0)) +np.mean(lh_flux_sfc - lh_flux_sfc_b,axis=(0)), label = "sum" )#, vrange = np.arange(-18,19,2))
# Text(0.5, 0, 'longitude (deg W)')

# %%
np.max(lh_flux_sfc_b)
# Out:
# 544.6402587890625
